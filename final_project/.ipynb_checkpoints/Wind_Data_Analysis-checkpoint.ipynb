# %%
import pandas as pd
from datetime import datetime, time, date
from matplotlib import pyplot as plt
import time
import calendar
import seaborn as sns

# %%
wind_speed = pd.read_csv('archive/wind_speed.csv')

# %%
# List of cities to use for my analysis
column_selection = ['datetime','time_of_day','day','Vancouver', 'Portland', 'San Francisco', 'Seattle','San Diego', 'Chicago', 'Detroit', 'Jacksonville', 'Miami', 'New York']

# %%
wind_speed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   datetime           45253 non-null  object
#  1   Vancouver          44458 non-null  float64
#  2   Portland           45252 non-null  float64
#  3   San Francisco      44459 non-null  float64
#  4   Seattle            45252 non-null  float64
#  5   Los Angeles        45252 non-null  float64
#  6   San Diego          45252 non-null  float64
#  7   Las Vegas          45238 non-null  float64
#  8   Phoenix            45251 non-null  float64
#  9   Albuquerque        45249 non-null  float64
#  10  Denver             45251 non-null  float64
#  11  San Antonio        45252 non-null  float64
#  12  Dallas             45251 non-null  float64
#  13  Houston            45250 non-null  float64
#  14  Kansas City        45252 non-null  float64
# ...

# %%
#Drop rows with NA data
wind_speed.dropna(inplace=True)

# %%
wind_speed
# Out:
#                  datetime  Vancouver  Portland  San Francisco  Seattle  \
# 37260 2017-01-01 00:00:00        5.0       3.0            2.0      5.0
# 37261 2017-01-01 01:00:00        5.0       2.0            1.0      5.0
# 37262 2017-01-01 02:00:00        7.0       3.0            2.0      5.0
# 37263 2017-01-01 03:00:00        5.0       2.0            3.0      3.0
# 37264 2017-01-01 04:00:00        3.0       1.0            1.0      3.0
# ...                   ...        ...       ...            ...      ...
# 44456 2017-10-27 20:00:00        2.0       6.0            0.0      2.0
# 44457 2017-10-27 21:00:00        2.0       8.0            2.0      3.0
# 44458 2017-10-27 22:00:00        4.0       8.0            2.0      1.0
# 44459 2017-10-27 23:00:00        0.0       6.0            2.0      3.0
# 44460 2017-10-28 00:00:00        4.0       5.0            2.0      2.0
#
#        Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  \
# ...

# %%
# Update datetime column to datetime
wind_speed['datetime'] = pd.to_datetime(wind_speed['datetime'])

# %%
wind_speed.where(wind_speed['datetime'] >= '2017-01-01 00:00:00', inplace=True)

# %%
wind_speed
# Out:
#                  datetime  Vancouver  Portland  San Francisco  Seattle  \
# 37260 2017-01-01 00:00:00        5.0       3.0            2.0      5.0
# 37261 2017-01-01 01:00:00        5.0       2.0            1.0      5.0
# 37262 2017-01-01 02:00:00        7.0       3.0            2.0      5.0
# 37263 2017-01-01 03:00:00        5.0       2.0            3.0      3.0
# 37264 2017-01-01 04:00:00        3.0       1.0            1.0      3.0
# ...                   ...        ...       ...            ...      ...
# 44456 2017-10-27 20:00:00        2.0       6.0            0.0      2.0
# 44457 2017-10-27 21:00:00        2.0       8.0            2.0      3.0
# 44458 2017-10-27 22:00:00        4.0       8.0            2.0      1.0
# 44459 2017-10-27 23:00:00        0.0       6.0            2.0      3.0
# 44460 2017-10-28 00:00:00        4.0       5.0            2.0      2.0
#
#        Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  \
# ...

# %%
# Create time of day column
wind_speed['time_of_day'] = wind_speed['datetime'].apply(lambda x: x.time())

# %%
# Create month column
wind_speed['month'] = wind_speed['datetime'].apply(lambda x: x.month)

# %%
wind_speed[wind_speed['month'] == 1]
# Out:
#                  datetime  Vancouver  Portland  San Francisco  Seattle  \
# 2196  2013-01-01 00:00:00        1.0       2.0            5.0      2.0
# 2197  2013-01-01 01:00:00        2.0       2.0            3.0      0.0
# 2198  2013-01-01 02:00:00        0.0       2.0            2.0      0.0
# 2199  2013-01-01 03:00:00        0.0       3.0            3.0      0.0
# 2200  2013-01-01 04:00:00        1.0       3.0            3.0      0.0
# ...                   ...        ...       ...            ...      ...
# 37999 2017-01-31 19:00:00        4.0       2.0            1.0      4.0
# 38000 2017-01-31 20:00:00        4.0       2.0            1.0      4.0
# 38001 2017-01-31 21:00:00        3.0       1.0            1.0      4.0
# 38002 2017-01-31 22:00:00        3.0       3.0            2.0      4.0
# 38003 2017-01-31 23:00:00        4.0       3.0            1.0      4.0
#
#        Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  \
# ...

# %%
wind_speed[column_selection]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-845bfbbb4970> in <module>
# ----> 1 wind_speed[column_selection]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ...

# %%
wind_speed['morning'] = (wind_speed['time_of_day'] >= time(9)) & (wind_speed['time_of_day'] <= time(12))
wind_speed['afternoon'] = (wind_speed['time_of_day'] >= time(13)) & (wind_speed['time_of_day'] <= time(16))

# %%
wind_speed[['datetime' ,'morning', 'afternoon']]
# Out:
#                  datetime  morning  afternoon
# 1     2012-10-01 13:00:00    False       True
# 2     2012-10-01 14:00:00    False       True
# 3     2012-10-01 15:00:00    False       True
# 4     2012-10-01 16:00:00    False       True
# 5     2012-10-01 17:00:00    False      False
# ...                   ...      ...        ...
# 44456 2017-10-27 20:00:00    False      False
# 44457 2017-10-27 21:00:00    False      False
# 44458 2017-10-27 22:00:00    False      False
# 44459 2017-10-27 23:00:00    False      False
# 44460 2017-10-28 00:00:00    False      False
#
# [44426 rows x 3 columns]

# %%
wind_speed['month'] = wind_speed['datetime'].apply(lambda x: x.month)

# %%
wind_speed
# Out:
#                  datetime  Vancouver  Portland  San Francisco  Seattle  \
# 1     2012-10-01 13:00:00        0.0       0.0            2.0      0.0
# 2     2012-10-01 14:00:00        0.0       0.0            2.0      0.0
# 3     2012-10-01 15:00:00        0.0       0.0            2.0      0.0
# 4     2012-10-01 16:00:00        0.0       0.0            2.0      0.0
# 5     2012-10-01 17:00:00        0.0       0.0            2.0      0.0
# ...                   ...        ...       ...            ...      ...
# 44456 2017-10-27 20:00:00        2.0       6.0            0.0      2.0
# 44457 2017-10-27 21:00:00        2.0       8.0            2.0      3.0
# 44458 2017-10-27 22:00:00        4.0       8.0            2.0      1.0
# 44459 2017-10-27 23:00:00        0.0       6.0            2.0      3.0
# 44460 2017-10-28 00:00:00        4.0       5.0            2.0      2.0
#
#        Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  \
# ...

# %%
wind_speed['day'] = wind_speed['datetime'].apply(lambda x: x.date())

# %%
wind_speed
# Out:
#                  datetime  Vancouver  Portland  San Francisco  Seattle  \
# 1     2012-10-01 13:00:00        0.0       0.0            2.0      0.0
# 2     2012-10-01 14:00:00        0.0       0.0            2.0      0.0
# 3     2012-10-01 15:00:00        0.0       0.0            2.0      0.0
# 4     2012-10-01 16:00:00        0.0       0.0            2.0      0.0
# 5     2012-10-01 17:00:00        0.0       0.0            2.0      0.0
# ...                   ...        ...       ...            ...      ...
# 44456 2017-10-27 20:00:00        2.0       6.0            0.0      2.0
# 44457 2017-10-27 21:00:00        2.0       8.0            2.0      3.0
# 44458 2017-10-27 22:00:00        4.0       8.0            2.0      1.0
# 44459 2017-10-27 23:00:00        0.0       6.0            2.0      3.0
# 44460 2017-10-28 00:00:00        4.0       5.0            2.0      2.0
#
#        Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque  ...  \
# ...

# %%
monthly_data = wind_speed.groupby('month').mean()
monthly_data
# Out:
#        Vancouver  Portland  San Francisco   Seattle  Los Angeles  San Diego  \
# month
# 1       1.930608  2.172673       2.349650  1.713556     1.104626   1.447552
# 2       2.391548  2.510047       3.190603  2.348109     0.959515   1.746749
# 3       2.692349  2.326509       3.136045  2.455550     1.253772   1.828933
# 4       2.589608  2.069742       3.814115  2.310086     1.464018   2.251181
# 5       1.993272  1.747847       3.398278  1.915501     1.514532   2.105490
# 6       2.113674  1.436631       2.237910  1.745136     1.188716   1.560033
# 7       2.558127  2.104413       2.828041  2.068891     1.660388   1.971744
# 8       2.557320  1.695102       2.555167  1.829117     1.319160   1.678418
# 9       2.507363  1.668519       2.623229  2.049458     1.256182   1.817171
# 10      2.423678  1.749885       2.294253  2.150345     0.857701   1.498851
# 11      2.754444  2.398611       2.327222  2.264444     1.023889   1.594444
# ...

# %%
daily_data = wind_speed[column_selection].groupby(['day']).mean()
daily_data
# Out:
#             Vancouver  Portland  San Francisco   Seattle  San Diego   Chicago  \
# day
# 2012-10-01   0.000000  0.000000       1.636364  0.000000   0.000000  0.000000
# 2012-10-02   0.000000  1.291667       1.708333  0.625000   1.125000  0.458333
# 2012-10-03   0.541667  2.625000       2.375000  1.583333   1.083333  4.291667
# 2012-10-04   0.625000  4.625000       2.791667  3.375000   1.000000  2.708333
# 2012-10-05   0.416667  3.708333       2.125000  2.625000   1.708333  3.250000
# ...               ...       ...            ...       ...        ...       ...
# 2017-10-24   1.708333  1.500000       2.875000  2.291667   1.916667  5.125000
# 2017-10-25   2.666667  1.333333       2.041667  2.250000   2.041667  3.375000
# 2017-10-26   3.166667  3.125000       1.458333  2.500000   1.250000  3.625000
# 2017-10-27   2.125000  4.125000       0.916667  2.875000   1.958333  6.250000
# 2017-10-28   4.000000  5.000000       2.000000  2.000000   3.000000  5.000000
#
# ...

# %%
wind_speed[column_selection].max()
# Out:
# datetime         2017-10-28 00:00:00
# time_of_day                 23:00:00
# Vancouver                         25
# Portland                          17
# San Francisco                     43
# Seattle                           24
# San Diego                         30
# Chicago                           25
# Detroit                           17
# Jacksonville                      20
# Miami                             28
# New York                          25
# dtype: object

# %%
# pd.melt(df, id_vars =['Name'], value_vars =['Course'], 
#               var_name ='ChangedVarname', value_name ='ChangedValname') 

wind_speed_updated = pd.melt(wind_speed[column_selection], id_vars=['datetime'], value_vars=['Vancouver', 'Portland', 'San Francisco', 'Seattle','San Diego', 'Chicago', 'Detroit', 'Jacksonville', 'Miami', 'New York'])

# %%
wind_speed_updated
# Out:
#                  datetime   variable  value
# 0     2017-01-01 00:00:00  Vancouver    5.0
# 1     2017-01-01 01:00:00  Vancouver    5.0
# 2     2017-01-01 02:00:00  Vancouver    7.0
# 3     2017-01-01 03:00:00  Vancouver    5.0
# 4     2017-01-01 04:00:00  Vancouver    3.0
# ...                   ...        ...    ...
# 71865 2017-10-27 20:00:00   New York    3.0
# 71866 2017-10-27 21:00:00   New York    1.0
# 71867 2017-10-27 22:00:00   New York    2.0
# 71868 2017-10-27 23:00:00   New York    3.0
# 71869 2017-10-28 00:00:00   New York    2.0
#
# [71870 rows x 3 columns]

# %%
wind_speed_updated['day'] = wind_speed_updated['datetime'].apply(lambda x: x.date())
wind_speed_updated['month'] = wind_speed_updated['datetime'].apply(lambda x: x.month)

# %%
wind_speed_updated
# Out:
#                  datetime   variable  value         day  month
# 0     2017-01-01 00:00:00  Vancouver    5.0  2017-01-01      1
# 1     2017-01-01 01:00:00  Vancouver    5.0  2017-01-01      1
# 2     2017-01-01 02:00:00  Vancouver    7.0  2017-01-01      1
# 3     2017-01-01 03:00:00  Vancouver    5.0  2017-01-01      1
# 4     2017-01-01 04:00:00  Vancouver    3.0  2017-01-01      1
# ...                   ...        ...    ...         ...    ...
# 71865 2017-10-27 20:00:00   New York    3.0  2017-10-27     10
# 71866 2017-10-27 21:00:00   New York    1.0  2017-10-27     10
# 71867 2017-10-27 22:00:00   New York    2.0  2017-10-27     10
# 71868 2017-10-27 23:00:00   New York    3.0  2017-10-27     10
# 71869 2017-10-28 00:00:00   New York    2.0  2017-10-28     10
#
# [71870 rows x 5 columns]

# %%
wind_speed_updated.rename(columns={'variable': 'City', 'value': 'Wind Speed'}, inplace=True)

# %%
wind_speed_updated['month_name'] = wind_speed_updated['month'].apply(lambda x: calendar.month_abbr[x])

# %%
wind_speed_updated
# Out:
#                  datetime       City  Wind Speed         day  month month_name
# 0     2017-01-01 00:00:00  Vancouver         5.0  2017-01-01      1        Jan
# 1     2017-01-01 01:00:00  Vancouver         5.0  2017-01-01      1        Jan
# 2     2017-01-01 02:00:00  Vancouver         7.0  2017-01-01      1        Jan
# 3     2017-01-01 03:00:00  Vancouver         5.0  2017-01-01      1        Jan
# 4     2017-01-01 04:00:00  Vancouver         3.0  2017-01-01      1        Jan
# ...                   ...        ...         ...         ...    ...        ...
# 71865 2017-10-27 20:00:00   New York         3.0  2017-10-27     10        Oct
# 71866 2017-10-27 21:00:00   New York         1.0  2017-10-27     10        Oct
# 71867 2017-10-27 22:00:00   New York         2.0  2017-10-27     10        Oct
# 71868 2017-10-27 23:00:00   New York         3.0  2017-10-27     10        Oct
# 71869 2017-10-28 00:00:00   New York         2.0  2017-10-28     10        Oct
#
# ...

# %%
wind_speed_updated['FairWind'] = (wind_speed_updated['Wind Speed'] >= 8) & (wind_speed_updated['Wind Speed'] <= 20)

# %%
wind_speed_updated[wind_speed_updated['FairWind'] == True]
# Out:
#                  datetime       City  Wind Speed         day  month  \
# 138   2017-01-06 18:00:00  Vancouver         8.0  2017-01-06      1
# 204   2017-01-09 12:00:00  Vancouver         9.0  2017-01-09      1
# 240   2017-01-11 00:00:00  Vancouver         8.0  2017-01-11      1
# 242   2017-01-11 02:00:00  Vancouver        14.0  2017-01-11      1
# 243   2017-01-11 03:00:00  Vancouver        12.0  2017-01-11      1
# ...                   ...        ...         ...         ...    ...
# 71776 2017-10-24 03:00:00   New York         8.0  2017-10-24     10
# 71788 2017-10-24 15:00:00   New York         9.0  2017-10-24     10
# 71792 2017-10-24 19:00:00   New York        10.0  2017-10-24     10
# 71793 2017-10-24 20:00:00   New York         9.0  2017-10-24     10
# 71794 2017-10-24 21:00:00   New York         9.0  2017-10-24     10
#
#       month_name  FairWind
# 138          Jan      True
# 204          Jan      True
# 240          Jan      True
# 242          Jan      True
# ...

# %%
# Number of fair wind days over the year
fair_wind = wind_speed_updated[wind_speed_updated['FairWind'] ==True].groupby(['City', 'day', 'month_name']).count()
fair_wind['FairWind']
# Out:
# City       day         month_name
# Chicago    2017-01-04  Jan           10
#            2017-01-05  Jan            1
#            2017-01-08  Jan            2
#            2017-01-10  Jan           12
#            2017-01-11  Jan            5
#                                      ..
# Vancouver  2017-09-18  Sep            1
#            2017-10-01  Oct            1
#            2017-10-10  Oct            1
#            2017-10-17  Oct            6
#            2017-10-18  Oct            3
# Name: FairWind, Length: 658, dtype: int64

# %%
wind_speed_updated
# Out:
#                  datetime       City  Wind Speed         day  month  \
# 0     2017-01-01 00:00:00  Vancouver         5.0  2017-01-01      1
# 1     2017-01-01 01:00:00  Vancouver         5.0  2017-01-01      1
# 2     2017-01-01 02:00:00  Vancouver         7.0  2017-01-01      1
# 3     2017-01-01 03:00:00  Vancouver         5.0  2017-01-01      1
# 4     2017-01-01 04:00:00  Vancouver         3.0  2017-01-01      1
# ...                   ...        ...         ...         ...    ...
# 71865 2017-10-27 20:00:00   New York         3.0  2017-10-27     10
# 71866 2017-10-27 21:00:00   New York         1.0  2017-10-27     10
# 71867 2017-10-27 22:00:00   New York         2.0  2017-10-27     10
# 71868 2017-10-27 23:00:00   New York         3.0  2017-10-27     10
# 71869 2017-10-28 00:00:00   New York         2.0  2017-10-28     10
#
#       month_name  FairWind
# 0            Jan     False
# 1            Jan     False
# 2            Jan     False
# 3            Jan     False
# ...

# %%
fair_wind = wind_speed_updated[wind_speed_updated['FairWind'] ==True]

# %%
fair_wind
# Out:
#                  datetime       City  Wind Speed         day  month  \
# 138   2017-01-06 18:00:00  Vancouver         8.0  2017-01-06      1
# 204   2017-01-09 12:00:00  Vancouver         9.0  2017-01-09      1
# 240   2017-01-11 00:00:00  Vancouver         8.0  2017-01-11      1
# 242   2017-01-11 02:00:00  Vancouver        14.0  2017-01-11      1
# 243   2017-01-11 03:00:00  Vancouver        12.0  2017-01-11      1
# ...                   ...        ...         ...         ...    ...
# 71776 2017-10-24 03:00:00   New York         8.0  2017-10-24     10
# 71788 2017-10-24 15:00:00   New York         9.0  2017-10-24     10
# 71792 2017-10-24 19:00:00   New York        10.0  2017-10-24     10
# 71793 2017-10-24 20:00:00   New York         9.0  2017-10-24     10
# 71794 2017-10-24 21:00:00   New York         9.0  2017-10-24     10
#
#       month_name  FairWind
# 138          Jan      True
# 204          Jan      True
# 240          Jan      True
# 242          Jan      True
# ...

# %%
fair_wind_days = fair_wind.groupby(['City', 'month_name', 'day']).agg({'Wind Speed': ['max']})

# %%
fair_wind_days_test = fair_wind.groupby(['City', 'month_name', 'day'])

# %%
fair_wind_days_test.get_group('Chicago')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-e69f38bc1671> in <module>
# ----> 1 fair_wind_days_test.get_group('Chicago')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in get_group(self, name, obj)
#     683             obj = self._selected_obj
#     684
# --> 685         inds = self._get_index(name)
#     686         if not len(inds):
#     687             raise KeyError(name)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _get_index(self, name)
#     505         Safe get index, translate keys for datelike to underlying repr.
#     506         """
# --> 507         return self._get_indices([name])[0]
#     508
#     509     @cache_readonly
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _get_indices(self, names)
# ...

# %%
fair_wind_days
# Out:
#                                 Wind Speed
#                                        max
# City      month_name day
# Chicago   Apr        2017-04-01        8.0
#                      2017-04-05       12.0
#                      2017-04-06       13.0
#                      2017-04-07        8.0
#                      2017-04-08        8.0
# ...                                    ...
# Vancouver Oct        2017-10-17       12.0
#                      2017-10-18        8.0
#           Sep        2017-09-12        8.0
#                      2017-09-14        8.0
#                      2017-09-18        9.0
#
# [658 rows x 1 columns]

# %%
find_wind_days_count = fair_wind_days.groupby(['City', 'month_name']).count()
find_wind_days_count
# find_wind_days_count.sort_values(by=['month_name', 'City'])
# Out:
#                      Wind Speed
#                             max
# City      month_name
# Chicago   Apr                17
#           Aug                 5
#           Feb                13
#           Jan                11
#           Jul                 5
# ...                         ...
# Vancouver Jun                 4
#           Mar                 5
#           May                 3
#           Oct                 4
#           Sep                 3
#
# [89 rows x 1 columns]

# %%
find_wind_days_count.rename(columns={'':'Days Count'}, inplace=True)

# %%
find_wind_days_count.columns
# Out:
# MultiIndex([('Wind Speed', 'max')],
#            )
